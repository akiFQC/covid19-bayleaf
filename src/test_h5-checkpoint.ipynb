# %%
import numpy as np
import h5py
from matplotlib import pyplot as plt
import pandas as pd
import pyhdf

# %%
ls ../data/**/*.h5
# Out:
# ../data/test_data/GC1SG1_20200516D08D_T0727_L2SG_LAI_Q_1000.h5

# %%
ls ../data/**/*.hdf -la
# Out:
# -rw-r--r-- 1 afukuchi docker 16560835  5月 31 11:32 ../data/test_data/MCD15A2H.A2020137.h27v06.006.2020148021544.hdf
# -rw-r--r-- 1 afukuchi docker  5613021  5月 31 12:04 ../data/test_data/MCD15A2H.A2020137.h29v08.006.2020148010856.hdf

# %%
with h5py.File('../data/test_data/GC1SG1_20200516D08D_T0727_L2SG_LAI_Q_1000.h5','r') as f:
    print(f.keys())    
    lst=f['Image_data/LAI_AVE']

    desc=lst.attrs['Data_description']
    errdn=lst.attrs['Error_DN']
    maxdn=lst.attrs['Maximum_valid_DN']
    mindn=lst.attrs['Minimum_valid_DN']
    slope=lst.attrs['Slope']
    offset=lst.attrs['Offset']
    unit=lst.attrs['Unit']
    ar = np.array(lst)
    valid = np.where( ar==errdn , -1, ar )
    value = valid*slope + offset
    print(value)
# Out:
# <KeysViewHDF5 ['Geometry_data', 'Global_attributes', 'Image_data', 'Processing_attributes']>
# [[ 1.05300005e+00  1.09700005e+00  1.03800005e+00 ... -1.00000005e-03
#   -1.00000005e-03 -1.00000005e-03]
#  [ 9.61000046e-01  1.13000005e+00  1.28500006e+00 ... -1.00000005e-03
#   -1.00000005e-03 -1.00000005e-03]
#  [ 1.19400006e+00  1.00700005e+00  9.14000043e-01 ... -1.00000005e-03
#   -1.00000005e-03 -1.00000005e-03]
#  ...
#  [-1.00000005e-03 -1.00000005e-03 -1.00000005e-03 ... -1.00000005e-03
#   -1.00000005e-03 -1.00000005e-03]
#  [-1.00000005e-03 -1.00000005e-03 -1.00000005e-03 ... -1.00000005e-03
#   -1.00000005e-03 -1.00000005e-03]
#  [-1.00000005e-03 -1.00000005e-03 -1.00000005e-03 ... -1.00000005e-03
#   -1.00000005e-03 -1.00000005e-03]]

# %%
plt.imshow(value)
plt.show()

# %%
with pyhdf.HDF.HDF("../data/test_data/MCD15A2H.A2020137.h27v06.006.2020148021544.hdf",'r') as f:
    print(f.keys())    
    lst=f['Image_data/LAI_AVE']

    desc=lst.attrs['Data_description']
    errdn=lst.attrs['Error_DN']
    maxdn=lst.attrs['Maximum_valid_DN']
    mindn=lst.attrs['Minimum_valid_DN']
    slope=lst.attrs['Slope']
    offset=lst.attrs['Offset']
    unit=lst.attrs['Unit']
    ar = np.array(lst)
    valid = np.where( ar==errdn , -1, ar )
    value = valid*slope + offset
    print(value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2ed8dfe98631> in <module>
# ----> 1 with pyhdf.HDF("../data/test_data/MCD15A2H.A2020137.h27v06.006.2020148021544.hdf",'r') as f:
#       2     print(f.keys())
#       3     lst=f['Image_data/LAI_AVE']
#       4
#       5     desc=lst.attrs['Data_description']
#
# AttributeError: module 'pyhdf' has no attribute 'HDF'

# %%
df = pd.read_hdf("../data/test_data/MCD15A2H.A2020137.h27v06.006.2020148021544.hdf")
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# ~/.cache/pypoetry/virtualenvs/covid19-tribes-BsClMMJT-py3.8/lib/python3.8/site-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#     654         try:
# --> 655             self._handle = tables.open_file(self._path, self._mode, **kwargs)
#     656         except IOError as err:  # pragma: no cover
#
# ~/.cache/pypoetry/virtualenvs/covid19-tribes-BsClMMJT-py3.8/lib/python3.8/site-packages/tables/file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     314     # Finally, create the File instance, and return it
# --> 315     return File(filename, mode, title, root_uep, filters, **kwargs)
#     316
#
# ~/.cache/pypoetry/virtualenvs/covid19-tribes-BsClMMJT-py3.8/lib/python3.8/site-packages/tables/file.py in __init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     777         # Now, it is time to initialize the File extension
# --> 778         self._g_new(filename, mode, **params)
#     779
#
# tables/hdf5extension.pyx in tables.hdf5extension.File._g_new()
#
# HDF5ExtError: HDF5 error back trace
#
#   File "H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "H5Fsuper.c", line 411, in H5F__super_read
#     file signature not found
#
# End of HDF5 error back trace
#
# Unable to open/create file '../data/test_data/MCD15A2H.A2020137.h27v06.006.2020148021544.hdf'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-b35feb038bb8> in <module>
# ----> 1 df = pd.read_hdf("../data/test_data/MCD15A2H.A2020137.h27v06.006.2020148021544.hdf")
#
# ~/.cache/pypoetry/virtualenvs/covid19-tribes-BsClMMJT-py3.8/lib/python3.8/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     395             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     396
# --> 397         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     398         # can't auto open/close if we are using an iterator
#     399         # so delegate to the iterator
#
# ~/.cache/pypoetry/virtualenvs/covid19-tribes-BsClMMJT-py3.8/lib/python3.8/site-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     535         self._fletcher32 = fletcher32
#     536         self._filters = None
# --> 537         self.open(mode=mode, **kwargs)
#     538
#     539     def __fspath__(self):
#
# ~/.cache/pypoetry/virtualenvs/covid19-tribes-BsClMMJT-py3.8/lib/python3.8/site-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#     685             # is not part of IOError, make it one
#     686             if self._mode == "r" and "Unable to open/create file" in str(err):
# --> 687                 raise IOError(str(err))
#     688             raise
#     689
#
# OSError: HDF5 error back trace
#
#   File "H5F.c", line 509, in H5Fopen
#     unable to open file
#   File "H5Fint.c", line 1400, in H5F__open
#     unable to open file
#   File "H5Fint.c", line 1700, in H5F_open
#     unable to read superblock
#   File "H5Fsuper.c", line 411, in H5F__super_read
#     file signature not found
#
# End of HDF5 error back trace
#
# Unable to open/create file '../data/test_data/MCD15A2H.A2020137.h27v06.006.2020148021544.hdf'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
